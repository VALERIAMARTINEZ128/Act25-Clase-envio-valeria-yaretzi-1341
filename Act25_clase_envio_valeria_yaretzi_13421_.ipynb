# %% [markdown]
# <a href="https://colab.research.google.com/github/VALERIAMARTINEZ128/Act25-Clase-envio-valeria-yaretzi-1341/blob/main/Act25_clase_envio_valeria_yaretzi_13421_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### valeria yaretzi lopez martinez NC = 2530805128**1341**
# #### fecha 27/abril/2026
# ### NL = 32
#
# ![texto vínculo](https://raw.githubusercontent.com/VALERIAMARTINEZ128/Act25-Clase-envio-valeria-yaretzi-1341/refs/heads/main/ChatGPT%20Image%2028%20abr%202026%2C%2012_39_53%20p.m..png)

# %%
# 1. Definimos la Clase 🏗️
class Envio:
    def __init__(self):
        # Los atributos se crean vacíos para llenarlos después
        self.destino = ""
        self.peso = ""
        self.costo = ""

    # Función para preguntar y leer los datos 📝
    def leerdatos(self, numero_envio):
        print(f"\n--- 📥 Capturando datos para el Envío #{numero_envio} ---")
        self.destino = input("¿A qué ciudad va el paquete?: ")
        self.peso = input("¿Cuánto pesa el paquete (kg)?: ")
        self.costo = input("¿Cuál es el costo del envío?: ")

    # Función para mostrar la información 📄
    def mostrardatos(self):
        print(f"📍 Destino: {self.destino}")
        print(f"⚖️ Peso: {self.peso}")
        print(f"💰 Costo: {self.costo}")
        print("-" * 30)
# --- 2. Creación de Objetos y Preguntas (Instancias) 👥 ---
# Creamos el primer objeto y le pedimos que pregunte sus datos
envio1 = Envio()
envio1.leerdatos(1)
# Creamos el segundo objeto y le pedimos que pregunte sus datos
envio2 = Envio()
envio2.leerdato(2)
# --- 3. Ejecución de la muestra de datos ---
print("\n" + "="*35)
print("📦 REPORTE FINAL DE ENVÍOS")
print("="*35)

print("DETALLES ENVÍO 1:")
envio1.mostrardatos()

print("DETALLES ENVÍO 2:")
envio2.mostrardatos()

print(f"Programa terminado por Valeria Yaretzi NL = 32")
# Out:
# --- 📥 Capturando datos para el Envío #1 ---
# ¿A qué ciudad va el paquete?: ciudad juarez
# ¿Cuánto pesa el paquete (kg)?: 25
# ¿Cuál es el costo del envío?: 200
#
# --- 📥 Capturando datos para el Envío #2 ---
# ¿A qué ciudad va el paquete?: oaxaca
# ¿Cuánto pesa el paquete (kg)?: 35
# ¿Cuál es el costo del envío?: 400
#
# ...
# 📦 REPORTE FINAL DE ENVÍOS
# ...
# DETALLES ENVÍO 1:
# 📍 Destino: ciudad juarez
# ⚖️ Peso: 25
# 💰 Costo: 200
# ------------------------------
# DETALLES ENVÍO 2:
# 📍 Destino: oaxaca
# ⚖️ Peso: 35
# 💰 Costo: 400
# ------------------------------
# Programa terminado por Valeria Yaretzi NL = 32

# %% [markdown]
# ![texto vínculo](https://raw.githubusercontent.com/VALERIAMARTINEZ128/Act25-Clase-envio-valeria-yaretzi-1341/refs/heads/main/shapes%20at%2026-04-28%2012.53.45.png)
